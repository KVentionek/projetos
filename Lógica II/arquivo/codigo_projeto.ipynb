# %%
nomes = [
    'Alice Silva',
    'Bernardo Santos',
    'Clara Oliveira',
    'Daniel Pereira',
    'Eloá Almeida',
    'Felipe Gomes',
    'Gabriela Costa',
    'Heitor Lima',
    'Isabela Rodrigues',
    'João Sousa',
    'Laura Carvalho',
    'Mateus Ferreira',
    'Nina Cardoso',
    'Otávio Martins',
    'Pietra Barbosa',
    'Rafael Castro',
    'Sophia Ribeiro',
    'Thiago Mendes',
    'Valentina Cunha',
    'Yuri Alves',
    'Amanda Oliveira',
    'Bruno Santos',
    'Carolina Lima',
    'Diego Fernandes',
    'Eduarda Carvalho',
    'Fábio Pereira',
    'Giovanna Costa',
    'Henrique Silva',
    'Isabella Almeida',
    'Júlio Rodrigues',
    'Larissa Sousa',
    'Marcelo Gomes',
    'Natália Cardoso',
    'Orlando Martins',
    'Paula Barbosa',
    'Ricardo Castro',
    'Sara Ribeiro',
    'Thales Mendes',
    'Vitória Cunha',
    'Wagner Alves',
    'Aline Oliveira',
    'Breno Santos',
    'Carla Lima',
    'Diogo Fernandes',
    'Elisa Carvalho',
    'Fernando Pereira',
    'Gabrielle Costa',
    'Hugo Lima',
    'Izabel Rodrigues',
    'José Sousa',
    'Lara Carvalho',
    'Maurício Ferreira',
    'Nádia Cardoso',
    'Oscar Martins',
    'Pâmela Barbosa',
    'Rafaela Castro',
    'Sônia Ribeiro',
    'Thierry Mendes',
    'Vanessa Cunha',
    'Wendell Alves',
    'Alessandra Oliveira',
    'Bruna Santos',
    'Carlos Lima',
    'Denise Fernandes',
    'Emanuela Carvalho',
    'Feliciano Pereira',
    'Giovana Costa',
    'Hélio Silva',
    'Ivone Almeida',
    'Jonas Rodrigues',
    'Larissa Sousa',
    'Marcos Gomes',
    'Natasha Cardoso',
    'Orlando Martins',
    'Priscila Barbosa',
    'Rafael Castro',
    'Simone Ribeiro',
    'Thiago Mendes',
    'Viviane Cunha',
    'Wilian Alves',
    'Alexandra Oliveira',
    'Benjamin Santos',
    'Camila Lima',
    'Daniel Fernandes',
    'Elisabete Carvalho',
    'Francisco Pereira',
    'Gabriela Costa',
    'Henrique Lima',
    'Isabel Rodrigues',
    'Joana Sousa',
    'Larissa Carvalho',
    'Marcelo Ferreira',
    'Natália Cardoso',
    'Orlando Martins',
    'Paulo Barbosa',
    'Rafael Castro',
    'Sandra Ribeiro',
    'Thiago Mendes',
    'Valéria Cunha',
    'Yasmin Alves'
]

# %%
cpfs = [
    '123.456.789-00',
    '234.567.890-11',
    '345.678.901-22',
    '456.789.012-33',
    '567.890.123-44',
    '678.901.234-55',
    '789.012.345-66',
    '890.123.456-77',
    '901.234.567-88',
    '012.345.678-99',
    '111.222.333-00',
    '222.333.444-11',
    '333.444.555-22',
    '444.555.666-33',
    '555.666.777-44',
    '666.777.888-55',
    '777.888.999-66',
    '888.999.000-77',
    '999.000.111-88',
    '000.111.222-99',
    '987.654.321-00',
    '876.543.210-11',
    '765.432.109-22',
    '654.321.098-33',
    '543.210.987-44',
    '432.109.876-55',
    '321.098.765-66',
    '210.987.654-77',
    '109.876.543-88',
    '098.765.432-99',
    '112.233.445-50',
    '224.466.880-12',
    '336.699.002-34',
    9.3, 5.4, 6.8, 8.3, 6.2, 9.8, 7.4, 7.8, 4.6, 6.4,
    9.4, 5.3, 6.7, 8.2, 6.3, 9.9, 7.5, 7.7, 4.4, 6.2,
    9.5, 5.2, 6.6, 8.1, 6.4, 9.8, 7.6, 7.6, 4.2, 6.0,
    9.6, 5.1, 6.5, 8.0, 6.5, 9.7, 7.7, 7.5, 4.0, 5.8
]

# %%
notas2 = [
    7.8, 6.3, 9.2, 5.9, 8.1, 7.4, 6.5, 8.7, 5.6, 9.0,
    6.9, 8.3, 7.2, 5.4, 9.4, 6.7, 8.9, 7.6, 5.2, 9.5,
    6.1, 8.5, 7.0, 5.7, 9.1, 6.6, 8.8, 7.3, 5.5, 9.3,
    5.8, 8.2, 7.5, 6.2, 9.7, 6.8, 8.6, 7.1, 5.3, 9.6,
    5.1, 8.0, 7.7, 6.4, 9.9, 6.5, 8.4, 7.8, 5.0, 9.8,
    7.9, 6.2, 9.2, 5.8, 8.1, 7.5, 6.7, 8.9, 5.4, 9.0,
    6.8, 8.3, 7.4, 5.6, 9.5, 6.6, 8.7, 7.2, 5.2, 9.4,
    6.7, 8.5, 7.3, 5.7, 9.3, 6.4, 8.8, 7.1, 5.5, 9.1,
    6.6, 8.2, 7.0, 5.3, 9.6, 6.3, 8.6, 7.0, 5.1, 9.7,
    6.5, 8.0, 7.9, 6.1, 9.8, 6.2, 8.4, 7.8, 5.0, 9.9
]

# %%
notas3 = [
    8.5, 6.9, 7.3, 9.1, 5.7, 8.2, 7.8, 6.4, 9.3, 5.2,
    7.6, 9.0, 6.1, 8.7, 5.9, 7.4, 9.2, 6.5, 8.9, 5.6,
    7.1, 9.4, 6.6, 8.3, 5.4, 7.9, 9.5, 6.7, 8.8, 5.3,
    6.8, 9.6, 6.9, 8.4, 5.1, 7.7, 9.7, 6.2, 8.6, 5.0,
    6.7, 9.8, 7.0, 8.5, 4.9, 7.5, 9.9, 6.3, 8.2, 4.8,
    6.6, 9.9, 7.1, 8.3, 4.7, 7.3, 9.8, 6.4, 8.1, 4.6,
    6.5, 9.7, 7.2, 8.4, 4.5, 7.1, 9.6, 6.5, 8.0, 4.4,
    6.4, 9.5, 7.3, 8.6, 4.3, 6.9, 9.4, 6.6, 7.9, 4.2,
    6.3, 9.3, 7.4, 8.7, 4.1, 6.7, 9.2, 6.7, 7.8, 4.0,
    6.2, 9.1, 7.5, 8.8, 3.9, 6.5, 9.0, 6.8, 7.7, 3.8
]

# %%
notas4 = [
    8.7, 6.5, 9.3, 7.1, 5.9, 8.4, 7.9, 6.3, 9.2, 7.5,
    8.1, 5.7, 9.6, 7.3, 6.1, 8.6, 7.7, 6.8, 9.1, 7.4,
    8.2, 5.5, 9.7, 7.5, 6.6, 8.8, 7.8, 6.9, 9.4, 7.6,
    8.3, 5.3, 9.8, 7.7, 6.7, 8.9, 7.9, 7.0, 9.5, 7.7,
    8.4, 5.1, 9.9, 7.9, 6.8, 9.0, 8.0, 7.1, 9.3, 7.8,
    8.5, 4.9, 8.9, 8.0, 6.9, 9.1, 8.1, 7.2, 9.2, 7.9,
    8.6, 4.7, 8.8, 8.2, 6.8, 9.2, 8.2, 7.3, 9.1, 7.8,
    8.7, 4.5, 8.7, 8.3, 6.7, 9.3, 8.3, 7.4, 9.0, 7.7,
    8.8, 4.3, 8.6, 8.4, 6.6, 9.4, 8.4, 7.5, 8.9, 7.6,
    8.9, 4.1, 8.5, 8.5, 6.5, 9.5, 8.5, 7.6, 8.8, 7.5
]

# %%
notas5 = [
    7.6, 9.0, 8.3, 6.7, 8.1, 7.9, 6.5, 8.8, 7.2, 5.4,
    8.4, 7.8, 6.3, 9.2, 8.7, 6.9, 8.2, 7.7, 6.1, 9.5,
    8.6, 7.5, 6.0, 9.3, 8.9, 6.8, 8.5, 7.4, 5.9, 9.1,
    8.8, 7.3, 5.8, 9.4, 9.0, 6.7, 8.6, 7.2, 5.6, 9.7,
    8.9, 7.1, 5.5, 9.6, 9.2, 6.6, 8.7, 7.1, 5.4, 9.8,
    9.0, 7.0, 5.3, 9.9, 9.3, 6.5, 8.8, 6.9, 5.2, 9.5,
    9.1, 6.9, 5.1, 9.8, 9.4, 6.4, 8.9, 6.8, 5.0, 9.6,
    9.2, 6.8, 5.0, 9.7, 9.5, 6.3, 9.0, 6.7, 4.9, 9.4,
    9.3, 6.7, 4.8, 9.6, 9.6, 6.2, 9.1, 6.6, 4.7, 9.3,
    9.4, 6.6, 4.6, 9.5, 9.7, 6.1, 9.2, 6.5, 4.5, 9.1
]

# %%
rematricula = ['Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Não', 'Sim', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não',
               'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não', 'Sim', 'Não']

# %%
import random

faltas = [random.randint(0, 100) for _ in range(100)]
print(faltas)

telefones = [f"({random.randint(10, 99)}) 9{random.randint(1000, 9999)}-{random.randint(1000, 9999)}" for _ in range(100)]
print(telefones)

mensalidades = [random.randint(0, 6) for _ in range(100)]
print(mensalidades)

cursos = ['Sistemas de Informação' if random.random() < 0.57 else 'Ciências da Computação' for _ in range(100)]
print(cursos)
# Out:
# [73, 79, 3, 19, 65, 8, 58, 59, 98, 53, 42, 48, 19, 66, 91, 85, 41, 98, 77, 42, 79, 97, 4, 32, 49, 84, 67, 91, 93, 61, 99, 0, 1, 51, 3, 14, 51, 56, 43, 51, 35, 36, 49, 90, 69, 60, 68, 53, 84, 31, 7, 45, 71, 9, 63, 74, 24, 0, 86, 48, 53, 13, 72, 42, 21, 83, 31, 81, 30, 91, 80, 31, 6, 41, 64, 95, 34, 37, 1, 62, 69, 14, 86, 73, 91, 9, 88, 77, 38, 35, 76, 74, 18, 46, 17, 37, 13, 54, 4, 48]
# ...

# %%
alunos = []
for x in nomes:
  alunos.append({'Nome': x})
print (alunos)
# Out:
# [{'Nome': 'Alice Silva'}, {'Nome': 'Bernardo Santos'}, {'Nome': 'Clara Oliveira'}, {'Nome': 'Daniel Pereira'}, {'Nome': 'Eloá Almeida'}, {'Nome': 'Felipe Gomes'}, {'Nome': 'Gabriela Costa'}, {'Nome': 'Heitor Lima'}, {'Nome': 'Isabela Rodrigues'}, {'Nome': 'João Sousa'}, {'Nome': 'Laura Carvalho'}, {'Nome': 'Mateus Ferreira'}, {'Nome': 'Nina Cardoso'}, {'Nome': 'Otávio Martins'}, {'Nome': 'Pietra Barbosa'}, {'Nome': 'Rafael Castro'}, {'Nome': 'Sophia Ribeiro'}, {'Nome': 'Thiago Mendes'}, {'Nome': 'Valentina Cunha'}, {'Nome': 'Yuri Alves'}, {'Nome': 'Amanda Oliveira'}, {'Nome': 'Bruno Santos'}, {'Nome': 'Carolina Lima'}, {'Nome': 'Diego Fernandes'}, {'Nome': 'Eduarda Carvalho'}, {'Nome': 'Fábio Pereira'}, {'Nome': 'Giovanna Costa'}, {'Nome': 'Henrique Silva'}, {'Nome': 'Isabella Almeida'}, {'Nome': 'Júlio Rodrigues'}, {'Nome': 'Larissa Sousa'}, {'Nome': 'Marcelo Gomes'}, {'Nome': 'Natália Cardoso'}, {'Nome': 'Orlando Martins'}, {'Nome': 'Paula Barbosa'}, {'Nome': 'Ricardo Castro'}, {'N
# ...

# %%
def add_ao_dict(chave, lista):
  for i, x in enumerate (lista):
    alunos[i][chave]=x

# %%
add_ao_dict('CPF', cpfs)
add_ao_dict('Matrícula', matriculas)
add_ao_dict('Notas (Prova 1)',notas1)
add_ao_dict('Notas (Prova 2)',notas2)
add_ao_dict('Notas (Prova 3)',notas3)
add_ao_dict('Notas (Prova 4)',notas4)
add_ao_dict('Notas (Prova 5)', notas5)
add_ao_dict('Rematrícula',rematricula)
add_ao_dict('Faltas', faltas)
add_ao_dict('Telefone', telefones)
add_ao_dict('Mensalidades em atraso', mensalidades)
add_ao_dict('Curso', cursos)
print (alunos)
# Out:
# [{'Nome': 'Alice Silva', 'CPF': '123.456.789-00', 'Matrícula': '202301', 'Notas (Prova 1)': 9.2, 'Notas (Prova 2)': 7.8, 'Notas (Prova 3)': 8.5, 'Notas (Prova 4)': 8.7, 'Notas (Prova 5)': 7.6, 'Rematrícula': 'Sim', 'Faltas': 73, 'Telefone': '(45) 92366-3297', 'Mensalidades em atraso': 5, 'Curso': 'Ciências da Computação'}, {'Nome': 'Bernardo Santos', 'CPF': '234.567.890-11', 'Matrícula': '202302', 'Notas (Prova 1)': 6.8, 'Notas (Prova 2)': 6.3, 'Notas (Prova 3)': 6.9, 'Notas (Prova 4)': 6.5, 'Notas (Prova 5)': 9.0, 'Rematrícula': 'Não', 'Faltas': 79, 'Telefone': '(24) 93655-2556', 'Mensalidades em atraso': 6, 'Curso': 'Sistemas de Informação'}, {'Nome': 'Clara Oliveira', 'CPF': '345.678.901-22', 'Matrícula': '202303', 'Notas (Prova 1)': 7.5, 'Notas (Prova 2)': 9.2, 'Notas (Prova 3)': 7.3, 'Notas (Prova 4)': 9.3, 'Notas (Prova 5)': 8.3, 'Rematrícula': 'Sim', 'Faltas': 3, 'Telefone': '(82) 93135-6950', 'Mensalidades em atraso': 0, 'Curso': 'Sistemas de Informação'}, {'Nome': 'Daniel Pe
# ...

# %%
import csv

nome_coluna = ['Nome', 'CPF', 'Matrícula', 'Notas (Prova 1)', 'Notas (Prova 2)', 'Notas (Prova 3)', 'Notas (Prova 4)', 'Notas (Prova 5)', 'Rematrícula', 'Faltas', 'Telefone', 'Mensalidades em atraso', 'Curso']


with open('alunos_matric.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames = nome_coluna)
    writer.writeheader()
    writer.writerows(alunos)
